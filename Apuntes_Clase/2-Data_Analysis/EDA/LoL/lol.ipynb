# %%
import numpy as np
import pandas as pd

# %%
lol = pd.read_csv("games.csv", sep= ",")

# %%
lol
# Out:
#            gameId   creationTime  gameDuration  seasonId  winner  firstBlood  \
# 0      3326086514  1504279457970          1949         9       1           2
# 1      3229566029  1497848803862          1851         9       1           1
# 2      3327363504  1504360103310          1493         9       1           2
# 3      3326856598  1504348503996          1758         9       1           1
# 4      3330080762  1504554410899          2094         9       1           2
# ...           ...            ...           ...       ...     ...         ...
# 51485  3308904636  1503076540231          1944         9       2           1
# 51486  3215685759  1496957179355          3304         9       2           1
# 51487  3322765040  1504029863961          2156         9       2           2
# 51488  3256675373  1499562036246          1475         9       2           2
# 51489  3317333020  1503612754059          1445         9       1           1
#
# ...

# %%
from io import StringIO

# %%
jDict = pd.read_json('champion_info_2.json')
champInfo = pd.read_json((jDict['data']).to_json(), orient='index')
champInfo.head()
# Out:
# C:\Users\Alumno-14\AppData\Local\Temp\ipykernel_19824\996919512.py:2: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   champInfo = pd.read_json((jDict['data']).to_json(), orient='index')
#                              tags                  title  id           key  \
# None                           []                   None  -1          None
# MonkeyKing        [Fighter, Tank]        the Monkey King  62    MonkeyKing
# Jax           [Fighter, Assassin]    Grandmaster at Arms  24           Jax
# Fiddlesticks      [Mage, Support]  the Harbinger of Doom   9  Fiddlesticks
# Shaco                  [Assassin]       the Demon Jester  35         Shaco
#
#                       name
# None                  None
# MonkeyKing          Wukong
# Jax                    Jax
# Fiddlesticks  Fiddlesticks
# Shaco                Shaco

# %%
champInfo = champInfo.set_index("name").sort_index()

# %%
champInfo
# Out:
#                         tags                   title   id      key
# name
# Aatrox       [Fighter, Tank]        the Darkin Blade  266   Aatrox
# Ahri        [Mage, Assassin]     the Nine-Tailed Fox  103     Ahri
# Akali             [Assassin]      the Fist of Shadow   84    Akali
# Alistar      [Tank, Support]            the Minotaur   12  Alistar
# Amumu           [Tank, Mage]           the Sad Mummy   32    Amumu
# ...                      ...                     ...  ...      ...
# Zac          [Tank, Fighter]       the Secret Weapon  154      Zac
# Zed      [Assassin, Fighter]   the Master of Shadows  238      Zed
# Ziggs                 [Mage]  the Hexplosives Expert  115    Ziggs
# Zilean       [Support, Mage]        the Chronokeeper   26   Zilean
# Zyra         [Mage, Support]      Rise of the Thorns  143     Zyra
#
# [139 rows x 4 columns]

# %%
spellJson = pd.read_json('summoner_spell_info.json')
spellInfo = pd.read_json((spellJson['data']).to_json(),orient='index')
spellInfo.head()
# Out:
# C:\Users\Alumno-14\AppData\Local\Temp\ipykernel_19824\1656119565.py:2: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   spellInfo = pd.read_json((spellJson['data']).to_json(),orient='index')
#    id  summonerLevel     name              key  \
# 1   1              6  Cleanse    SummonerBoost
# 3   3              4  Exhaust  SummonerExhaust
# 4   4              8    Flash    SummonerFlash
# 6   6              1    Ghost    SummonerHaste
# 7   7              1     Heal     SummonerHeal
#
#                                          description
# 1  Removes all disables (excluding suppression an...
# 3  Exhausts target enemy champion, reducing their...
# 4  Teleports your champion a short distance towar...
# 6  Your champion gains increased Movement Speed a...
# 7  Restores 90-345 Health (depending on champion ...
